# %%
import numpy as np
from SmartTruck import SmartTruck
from kalmanfilter2 import KalmanFilter
from simulation import Simulation

# %%
ds = 2 # dimensions
t = 10 # number of time steps to run
dt = 0.1 # time step length
ep_mag = 10 # process noise variation
ep_dir = np.array([0.5])
nu = 0.4 # measurement noise variation (both position and velocity)
initial = np.ones(ds*2)
initial.shape = (ds*2,1)

gen = SmartTruck(initial, t, dt, ep_mag, ep_dir, nu)
sim = Simulation(gen, KalmanFilter)

# %%
sim.generate()
sim.predict()
sim.plot()
# Out:
# [[0.79277515]
#  [0.86241138]]
# Our results:  0.0
# Scipy's results:  0.0
# [[1.59013598]
#  [0.68239769]]
# Our results:  0.40647948317688537
# Scipy's results:  0.40647948317688537
# [[2.19609723]
#  [0.48688528]]
# Our results:  0.681100821890537
# Scipy's results:  0.681100821890537
# [[1.2683826 ]
#  [0.21760945]]
# Our results:  0.47123701168701504
# Scipy's results:  0.47123701168701504
# [[ 1.16116434]
#  [-1.59651799]]
# Our results:  2.167333232676678
# Scipy's results:  2.167333232676678
# [[ 2.66225553]
#  [-5.13379349]]
# Our results:  5.560162262081313
# Scipy's results:  5.560162262081313
# [[ 2.18124399]
#  [-9.86456243]]
# Our results:  9.7584400706607
# Scipy's results:  9.7584400706607
# [[  1.25158929]
#  [-13.49393933]]
# Our results:  12.495094536033694
# Scipy's results:  12.495094536033694
# [[ -1.61632808]
#  [-17.92475901]]
# Our results:  16.245754277094083
# Scipy's results:  16.245754277094083
# [[ -4.04089515]
#  [-21.51063703]]
# Our results:  18.985273969176912
# Scipy's results:  18.985273969176912
